# %% [markdown]
# # India High School Exoplanet Data Challenge
# **Enterprise Execution Environment**
#
# This notebook clones your GitHub repository, installs all the advanced Physics-Informed Neural Network (PINN) dependencies, and runs the entire training pipeline in the cloud.

# %%
# Step 1: Download your repository
# !git clone https://github.com/AdityaDevXYZ/india-exoplanet-challenge.git
# %cd india-exoplanet-challenge

# Step 2: Install dependencies (PyTorch, UMAP, Plotly, etc.)
# !pip install -r requirements.txt

# Step 3: Run the Advanced Training Pipeline!
# !python src/train_advanced.py

# %% [markdown]
# ## View the Output Map
# Once the cell above finishes running, it will generate an interactive HTML file at `reports/figures/latent_space_map.html`.
# Run the cell below to display the map directly in this notebook so you can take a screenshot!

# %%
import IPython
IPython.display.HTML(filename='reports/figures/latent_space_map.html')
